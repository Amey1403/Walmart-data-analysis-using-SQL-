# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
t=pd.read_csv("Walmart.csv",lineterminator="\n")

# %%
t
# Out:
#        invoice_id   Branch         City                category unit_price  \
# 0               1  WALM003  San Antonio       Health and beauty    $74.69
# 1               2  WALM048    Harlingen  Electronic accessories    $15.28
# 2               3  WALM067  Haltom City      Home and lifestyle        Nan
# 3               4  WALM064      Bedford       Health and beauty    $58.22
# 4               5  WALM013       Irving       Sports and travel    $86.31
# ...           ...      ...          ...                     ...        ...
# 10046        9996  WALM056      Rowlett     Fashion accessories       $37
# 10047        9997  WALM030   Richardson      Home and lifestyle       $58
# 10048        9998  WALM050     Victoria     Fashion accessories       $52
# 10049        9999  WALM032        Tyler      Home and lifestyle       $79
# 10050       10000  WALM069     Rockwall     Fashion accessories       $62
#
#        quantity      date      time payment_method  rating  profit_margin\r
# ...

# %%
t.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10051 entries, 0 to 10050
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   invoice_id      10051 non-null  int64
#  1   Branch          10051 non-null  object
#  2   City            10051 non-null  object
#  3   category        10051 non-null  object
#  4   unit_price      10011 non-null  object
#  5   quantity        10020 non-null  float64
#  6   date            10051 non-null  object
#  7   time            10051 non-null  object
#  8   payment_method  10051 non-null  object
#  9   rating          10051 non-null  float64
#   10051 non-null  float64
# dtypes: float64(3), int64(1), object(7)
# memory usage: 863.9+ KB

# %%
t.isnull().sum()
# Out:
# invoice_id          0
# Branch              0
# City                0
# category            0
# unit_price         40
# quantity           31
# date                0
# time                0
# payment_method      0
# rating              0
# profit_margin\r     0
# dtype: int64

# %%
t['unit_price'] = t['unit_price'].replace('Nan', np.nan)  # Replace string 'Nan' with actual NaN
t['unit_price'] = t['unit_price'].str.replace('$', '', regex=False)  # Remove dollar sign
t['unit_price'] = pd.to_numeric(t['unit_price'],errors="coerce")  # Convert to float

# %%
t
# Out:
#        invoice_id   Branch         City                category  unit_price  \
# 0               1  WALM003  San Antonio       Health and beauty       74.69
# 1               2  WALM048    Harlingen  Electronic accessories       15.28
# 2               3  WALM067  Haltom City      Home and lifestyle         NaN
# 3               4  WALM064      Bedford       Health and beauty       58.22
# 4               5  WALM013       Irving       Sports and travel       86.31
# ...           ...      ...          ...                     ...         ...
# 10046        9996  WALM056      Rowlett     Fashion accessories       37.00
# 10047        9997  WALM030   Richardson      Home and lifestyle       58.00
# 10048        9998  WALM050     Victoria     Fashion accessories       52.00
# 10049        9999  WALM032        Tyler      Home and lifestyle       79.00
# 10050       10000  WALM069     Rockwall     Fashion accessories       62.00
#
# ...

# %%
t.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10051 entries, 0 to 10050
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   invoice_id      10051 non-null  int64
#  1   Branch          10051 non-null  object
#  2   City            10051 non-null  object
#  3   category        10051 non-null  object
#  4   unit_price      10008 non-null  float64
#  5   quantity        10020 non-null  float64
#  6   date            10051 non-null  object
#  7   time            10051 non-null  object
#  8   payment_method  10051 non-null  object
#  9   rating          10051 non-null  float64
#   10051 non-null  float64
# dtypes: float64(4), int64(1), object(6)
# memory usage: 863.9+ KB

# %%
t['unit_price'] = t['unit_price'].fillna(100.0)

# %%
t
# Out:
#        invoice_id   Branch         City                category  unit_price  \
# 0               1  WALM003  San Antonio       Health and beauty       74.69
# 1               2  WALM048    Harlingen  Electronic accessories       15.28
# 2               3  WALM067  Haltom City      Home and lifestyle      100.00
# 3               4  WALM064      Bedford       Health and beauty       58.22
# 4               5  WALM013       Irving       Sports and travel       86.31
# ...           ...      ...          ...                     ...         ...
# 10046        9996  WALM056      Rowlett     Fashion accessories       37.00
# 10047        9997  WALM030   Richardson      Home and lifestyle       58.00
# 10048        9998  WALM050     Victoria     Fashion accessories       52.00
# 10049        9999  WALM032        Tyler      Home and lifestyle       79.00
# 10050       10000  WALM069     Rockwall     Fashion accessories       62.00
#
# ...

# %%
t.isnull().sum()
# Out:
# invoice_id          0
# Branch              0
# City                0
# category            0
# unit_price          0
# quantity           31
# date                0
# time                0
# payment_method      0
# rating              0
# profit_margin\r     0
# dtype: int64

# %%
t.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10051 entries, 0 to 10050
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   invoice_id      10051 non-null  int64
#  1   Branch          10051 non-null  object
#  2   City            10051 non-null  object
#  3   category        10051 non-null  object
#  4   unit_price      10051 non-null  float64
#  5   quantity        10020 non-null  float64
#  6   date            10051 non-null  object
#  7   time            10051 non-null  object
#  8   payment_method  10051 non-null  object
#  9   rating          10051 non-null  float64
#   10051 non-null  float64
# dtypes: float64(4), int64(1), object(6)
# memory usage: 863.9+ KB

# %%
t["date"]=pd.to_datetime(t["date"],errors="coerce") 

t["time"]=pd.to_datetime(t["time"],errors="coerce")
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_24724\1338779011.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   t["time"]=pd.to_datetime(t["time"],errors="coerce")

# %%
t.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10051 entries, 0 to 10050
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   invoice_id      10051 non-null  int64
#  1   Branch          10051 non-null  object
#  2   City            10051 non-null  object
#  3   category        10051 non-null  object
#  4   unit_price      10051 non-null  float64
#  5   quantity        10020 non-null  float64
#  6   date            3982 non-null   datetime64[ns]
#  7   time            10051 non-null  datetime64[ns]
#  8   payment_method  10051 non-null  object
#  9   rating          10051 non-null  float64
#   10051 non-null  float64
# dtypes: datetime64[ns](2), float64(4), int64(1), object(4)
# memory usage: 863.9+ KB

# %%
t.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10046     True
# 10047     True
# 10048     True
# 10049     True
# 10050     True
# Length: 10051, dtype: bool

# %%
t.duplicated().sum()
# Out:
# np.int64(51)

# %%
t.drop_duplicates(inplace=True)

# %%
t.duplicated().sum()
# Out:
# np.int64(0)

# %%
t.shape
# Out:
# (10000, 11)

# %%
t.dropna(inplace=True)

# %%
t.shape
# Out:
# (3952, 11)

# %%
t.isnull().sum()
# Out:
# invoice_id         0
# Branch             0
# City               0
# category           0
# unit_price         0
# quantity           0
# date               0
# time               0
# payment_method     0
# rating             0
# profit_margin\r    0
# dtype: int64

# %%
t.columns
# Out:
# Index(['invoice_id', 'Branch', 'City', 'category', 'unit_price', 'quantity',
#        'date', 'time', 'payment_method', 'rating', 'profit_margin\r'],
#       dtype='object')

# %%
t
# Out:
#       invoice_id   Branch         City                category  unit_price  \
# 0              1  WALM003  San Antonio       Health and beauty       74.69
# 1              2  WALM048    Harlingen  Electronic accessories       15.28
# 2              3  WALM067  Haltom City      Home and lifestyle      100.00
# 4              5  WALM013       Irving       Sports and travel       86.31
# 8              9  WALM066    Grapevine       Health and beauty       36.26
# ...          ...      ...          ...                     ...         ...
# 9989        9990  WALM086    Rosenberg     Fashion accessories       56.00
# 9990        9991  WALM074      Weslaco      Home and lifestyle       35.00
# 9991        9992  WALM087   Waxahachie     Fashion accessories       48.00
# 9992        9993  WALM073       Seguin      Home and lifestyle       31.00
# 9995        9996  WALM056      Rowlett     Fashion accessories       37.00
#
# ...

# %%
t.to_csv("walmart_clean.csv",index=False)
